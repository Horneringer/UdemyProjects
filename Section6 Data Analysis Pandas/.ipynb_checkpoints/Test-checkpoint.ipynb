# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'debug.log',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Test.ipynb']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1.shape
# Out:
# (6, 7)

# %%
df2 = pandas.read_json("supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df2.loc[3:5,"City":"Name"]
# Out:
#             City Country  Employees  ID        Name
# 3  San Francisco     USA         10   4  Ben's Shop
# 4  San Francisco     USA         12   5     Sanchez
# 5  San Francisco     USA         20   6  Richvalley

# %%
list(df2.loc[:,"City"])
# Out:
# ['San Francisco',
#  'San Francisco',
#  'San Francisco',
#  'San Francisco',
#  'San Francisco',
#  'San Francisco']

# %%
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df2.iloc[:,0:4]
# Out:
#            Address           City Country  Employees
# 0     3666 21st St  San Francisco     USA          8
# 1   735 Dolores St  San Francisco     USA         15
# 2      332 Hill St  San Francisco     USA         25
# 3     3995 23rd St  San Francisco     USA         10
# 4  1056 Sanchez St  San Francisco     USA         12
# 5  551 Alvarado St  San Francisco     USA         20

# %%
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2.ix[3,"Name"]
# Out:
# d:\python 3.6.3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# "Ben's Shop"

# %%
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2.drop("Name",1)
# Out:
#            Address           City Country  Employees  ID             State
# 0     3666 21st St  San Francisco     USA          8   1          CA 94114
# 1   735 Dolores St  San Francisco     USA         15   2          CA 94119
# 2      332 Hill St  San Francisco     USA         25   3  California 94114
# 3     3995 23rd St  San Francisco     USA         10   4          CA 94114
# 4  1056 Sanchez St  San Francisco     USA         12   5        California
# 5  551 Alvarado St  San Francisco     USA         20   6          CA 94114

# %%
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2.drop("735 Dolores S")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-5349cd6f3525> in <module>()
# ----> 1 df2.drop("735 Dolores S")
#
# d:\python 3.6.3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# d:\python 3.6.3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
df2.set_index("Address")
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2 = df2.set_index("Address")

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2.drop("735 Dolores St",0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-edd419430393> in <module>()
# ----> 1 df2.drop("735 Dolores St",0)
#
# d:\python 3.6.3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# d:\python 3.6.3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2.index
# Out:
# Index(['3666 21st St', '332 Hill St', '3995 23rd St', '1056 Sanchez St',
#        '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2["Continent"] = df2.shape[0]*["North America"]
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State      Continent
# Address
# 3666 21st St             CA 94114  North America
# 332 Hill St      California 94114  North America
# 3995 23rd St             CA 94114  North America
# 1056 Sanchez St        California  North America
# 551 Alvarado St          CA 94114  North America

# %%
df2["Continent"]=df2["Country"]+","+"North America"
df2
# Out:
#                           City Country Employees ID                Name  \
# Address
# 3666 21st St     San Francisco     USA         8  1             Madeira
# 332 Hill St      San Francisco     USA        25  3         Super River
# 3995 23rd St     San Francisco     USA        10  4          Ben's Shop
# 1056 Sanchez St  San Francisco     USA        12  5             Sanchez
# 551 Alvarado St  San Francisco     USA        20  6          Richvalley
# Okskyi 3B              Kolomna  Russia         8  7  Horneringer's Guns
#
#                             State             Continent
# Address
# 3666 21st St             CA 94114     USA,North America
# 332 Hill St      California 94114     USA,North America
# 3995 23rd St             CA 94114     USA,North America
# 1056 Sanchez St        California     USA,North America
# 551 Alvarado St          CA 94114     USA,North America
# Okskyi 3B           Moscow Region  Russia,North America

# %%
df2_t=df2.T
df2_t
# Out:
# Address                 3666 21st St                332 Hill St  \
# City                   San Francisco              San Francisco
# Country                          USA                        USA
# Employees                          8                         25
# ID                                 1                          3
# Name                         Madeira                Super River
# State                       CA 94114           California 94114
# Continent  USA,USA,USA,North America  USA,USA,USA,North America
#
# Address                 3995 23rd St            1056 Sanchez St  \
# City                   San Francisco              San Francisco
# Country                          USA                        USA
# Employees                         10                         12
# ID                                 4                          5
# Name                      Ben's Shop                    Sanchez
# State                       CA 94114                 California
# ...

# %%
df2_t["Okskyi 3B"]=["Kolomna", "Russia", 8,7,"Horneringer's Guns","Moscow Region", "Europe"]
df2_t
# Out:
# Address                 3666 21st St                332 Hill St  \
# City                   San Francisco              San Francisco
# Country                          USA                        USA
# Employees                          8                         25
# ID                                 1                          3
# Name                         Madeira                Super River
# State                       CA 94114           California 94114
# Continent  USA,USA,USA,North America  USA,USA,USA,North America
#
# Address                 3995 23rd St            1056 Sanchez St  \
# City                   San Francisco              San Francisco
# Country                          USA                        USA
# Employees                         10                         12
# ID                                 4                          5
# Name                      Ben's Shop                    Sanchez
# State                       CA 94114                 California
# ...

# %%
df2=df2_t.T
df2
# Out:
#                           City Country Employees ID                Name  \
# Address
# 3666 21st St     San Francisco     USA         8  1             Madeira
# 332 Hill St      San Francisco     USA        25  3         Super River
# 3995 23rd St     San Francisco     USA        10  4          Ben's Shop
# 1056 Sanchez St  San Francisco     USA        12  5             Sanchez
# 551 Alvarado St  San Francisco     USA        20  6          Richvalley
# Okskyi 3B              Kolomna  Russia         8  7  Horneringer's Guns
#
#                             State             Continent
# Address
# 3666 21st St             CA 94114     USA,North America
# 332 Hill St      California 94114     USA,North America
# 3995 23rd St             CA 94114     USA,North America
# 1056 Sanchez St        California     USA,North America
# 551 Alvarado St          CA 94114     USA,North America
# Okskyi 3B           Moscow Region  Russia,North America

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'units',
#  'util']

# %%
from geopy.geocoders import GoogleV3
nom = GoogleV3(scheme = "http")

# %%
myadr=nom.geocode("Окский 3Б, Коломна, Московская область")

# %%
myadr.latitude
# Out:
# 55.082325

# %%
myadr.longitude
# Out:
# 38.8026589
